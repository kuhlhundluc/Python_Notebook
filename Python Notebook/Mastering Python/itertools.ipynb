# %%
import operator
import itertools

#Sales per month
months = [10,8,5,7,12,10,5,8,15,3,4,2]
list(itertools.accumulate(months, operator.add))
# Out:
# [10, 18, 23, 30, 42, 52, 57, 65, 80, 83, 87, 89]

# %%
import itertools
a = range(3)
b = range(5)
list(itertools.chain(a,b))
# Out:
# [0, 1, 2, 0, 1, 2, 3, 4]

# %%
import itertools

list(itertools.combinations(range(3), 2))
# Out:
# [(0, 1), (0, 2), (1, 2)]

# %%
import itertools

tuple_string = 'r','g','u','o','e','m'

list(itertools.permutations(tuple_string,6))
# Out:
# [('r', 'g', 'u', 'o', 'e', 'm'),
#  ('r', 'g', 'u', 'o', 'm', 'e'),
#  ('r', 'g', 'u', 'e', 'o', 'm'),
#  ('r', 'g', 'u', 'e', 'm', 'o'),
#  ('r', 'g', 'u', 'm', 'o', 'e'),
#  ('r', 'g', 'u', 'm', 'e', 'o'),
#  ('r', 'g', 'o', 'u', 'e', 'm'),
#  ('r', 'g', 'o', 'u', 'm', 'e'),
#  ('r', 'g', 'o', 'e', 'u', 'm'),
#  ('r', 'g', 'o', 'e', 'm', 'u'),
#  ('r', 'g', 'o', 'm', 'u', 'e'),
#  ('r', 'g', 'o', 'm', 'e', 'u'),
#  ('r', 'g', 'e', 'u', 'o', 'm'),
#  ('r', 'g', 'e', 'u', 'm', 'o'),
#  ('r', 'g', 'e', 'o', 'u', 'm'),
#  ('r', 'g', 'e', 'o', 'm', 'u'),
#  ('r', 'g', 'e', 'm', 'u', 'o'),
#  ('r', 'g', 'e', 'm', 'o', 'u'),
#  ('r', 'g', 'm', 'u', 'o', 'e'),
#  ('r', 'g', 'm', 'u', 'e', 'o'),
#  ('r', 'g', 'm', 'o', 'u', 'e'),
#  ('r', 'g', 'm', 'o', 'e', 'u'),
#  ('r', 'g', 'm', 'e', 'u', 'o'),
#  ('r', 'g', 'm', 'e', 'o', 'u'),
#  ('r', 'u', 'g', 'o', 'e', 'm'),
#  ('r', 'u', 'g', 'o', 'm', 'e'),
#  ('r', 'u', 'g', 'e', 'o', 'm'),
#  ('r', 'u', 'g', 'e', 'm', 'o'),
# ...

# %%
#for later
import json
import itertools

tuple_string = [r,g,u,o,e,m]


collection = json.load(open("collection.json"))

def lookup(word):
    #word = word.lower()
    if word in collection:
        print("Here's a word")
    
words = list(itertools.permutations(tuple_string,6))

for word in words:
    lookup(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-ec7655bd447b> in <module>
#       2 import itertools
#       3
# ----> 4 tuple_string = [r,g,u,o,e,m]
#       5
#       6
#
# NameError: name 'r' is not defined
